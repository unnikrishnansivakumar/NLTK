# %%
import nltk

# %%
from nltk.book import *
from nltk.util import ngrams
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
text1.similar("monstrous")
# Out:
# imperial subtly impalpable pitiable curious abundant perilous
# trustworthy untoward singular lamentable few determined maddens
# horrible tyrannical lazy mystifying christian exasperate

# %%
text1.common_contexts(["mysterious","strange"])
# Out:
# a_fatality

# %%
text4.dispersion_plot(["citizens","freedom","democracy"])

# %%
def lx_rich(t):
    return float(len(set(t)))/float(len(t))

# %%
#counting vocab
len(text1)
# Out:
# 260819

# %%
#extracting each word

set(text1)
# Out:
# {u'funereal',
#  u'unscientific',
#  u'divinely',
#  u'foul',
#  u'four',
#  u'gag',
#  u'prefix',
#  u'woods',
#  u'clotted',
#  u'Duck',
#  u'hanging',
#  u'plaudits',
#  u'woody',
#  u'Until',
#  u'marching',
#  u'disobeying',
#  u'canes',
#  u'granting',
#  u'advantage',
#  u'Westers',
#  u'insertion',
#  u'DRYDEN',
#  u'formless',
#  u'Untried',
#  u'superficially',
#  u'vesper',
#  u'Western',
#  u'portentous',
#  u'meadows',
#  u'sinking',
#  u'Ding',
#  u'Spurn',
#  u'treasuries',
#  u'churned',
#  u'oceans',
#  u'powders',
#  u'tinkerings',
#  u'tantalizing',
#  u'yellow',
#  u'bolting',
#  u'uncertain',
#  u'stabbed',
#  u'bringing',
#  u'elevations',
#  u'ferreting',
#  u'wooded',
#  u'songster',
#  u'uttering',
#  u'scholar',
#  u'Less',
#  u'wooden',
#  u'Saco',
#  u'clings',
#  u'piling',
#  u'broiled',
#  u'Winding',
#  u'persisted',
#  u'Does',
#  u'Sands',
#  u'crotch',
#  u'succession',
#  u'spindle',
#  u'Paul',
#  u'reliable',
#  u'Bolivia',
#  u'ornamental',
#  u'charter',
#  u'puissant',
#  u'sooty',
#  u'nigh',
#  u'heaped',
#  u'miller',
#  u'cordially',
#  u'railing',
#  u'mail',
#  u'leisurely',
#  u'pulse',
#  u'elegant',
#  u'second',
#  u'Hecla',
#  u'valiant',
#  u'sustaining',
#  u'compliance',
#  u'sailed',
#  u'scraped',
#  u'haughtily',
#  u'bolts',
#  u'hilariously',
#  u'errors',
#  u'relieving',
#  u'whaling',
#  u'BERMUDAS',
#  u'ruthless',
#  u'thunder',
#  u'cooking',
#  u'contributed',
#  u'fingers',
#  u'shamble',
#  u'hostile',
#  u'fossil',
#  u'sneering',
#  u'College',
#  u'increasing',
#  u'admiral',
#  u'exclamations',
#  u'shocks',
#  u'psalmody',
#  u'avers',
#  u'hero',
#  u'intellects',
#  u'Plate',
#  u'gayer',
#  u'leaning',
#  u'here',
#  u'herd',
#  u'reported',
#  u'Fiery',
#  u'primogenitures',
#  u'gaffs',
#  u'fissures',
#  u'browed',
#  u'shriek',
#  u'calculate',
#  u'natured',
#  u'invade',
#  u'bulkhead',
#  u'substance',
#  u'whiffs',
#  u'unwillingness',
#  u'elaborate',
#  u'climbed',
#  u'unfriendly',
#  u'reports',
#  u'Yonder',
#  u'circumferences',
#  u'electricity',
#  u'misgrown',
#  u'transfixed',
#  u'natures',
#  u'NOT',
#  u'military',
#  u'Isles',
#  u'rebel',
#  u'punctilious',
#  u'golden',
#  u'divide',
#  u'classification',
#  u'secluded',
#  u'sweetest',
#  u'SAMUEL',
#  u'precincts',
#  u'Three',
#  u'shabbily',
#  u'summons',
#  u'brought',
#  u'Hardicanutes',
#  u'remnant',
#  u'stern',
#  u'Wales',
#  u'sinew',
#  u'painters',
#  u'cherishing',
#  u'cheating',
#  u'spoke',
#  u'handedness',
#  u'exhort',
#  u'glimmering',
#  u'cannibal',
#  u'accommodation',
#  u'occupying',
#  u'moth',
#  u'reverenced',
#  u'music',
#  u'therefore',
#  u'passport',
#  u'violently',
#  u'strike',
#  u'fossiliferous',
#  u'until',
#  u'icebound',
#  u'suffocated',
#  u'Blind',
#  u'females',
#  u'holy',
#  u'successful',
#  u'Biographical',
#  u'hereby',
#  u'whirling',
#  u'canonized',
#  u'hurt',
#  u'99',
#  u'glass',
#  u'diademed',
#  u'menaced',
#  u'tying',
#  u'lord',
#  u'91',
#  u'90',
#  u'midst',
#  u'hold',
#  u'extorting',
#  u'whalebone',
#  u'97',
#  u'circumstances',
#  u'tastefully',
#  u'morally',
#  u'PREBLE',
#  u'archaeological',
#  u'pursue',
#  u'famed',
#  u'blade',
#  u'plunged',
#  u'Chilian',
#  u'locker',
#  u'cuttle',
#  u'View',
#  u'leaped',
#  u'moidores',
#  u'Holloa',
#  u'apoplexy',
#  u'ELLERY',
#  u'example',
#  u'misfortunes',
#  u'temper',
#  u'wand',
#  u'La',
#  u'Lo',
#  u'household',
#  u'OWEN',
#  u'organized',
#  u'Reality',
#  u'Tartarian',
#  u'caution',
#  u'kingdoms',
#  u'want',
#  u'Unicornism',
#  u'jure',
#  u'cobbling',
#  u'absolute',
#  u'provincial',
#  u'enlist',
#  u'hoe',
#  u'hob',
#  u'groaned',
#  u'auger',
#  u'travel',
#  u'cavaliers',
#  u'subtleness',
#  u'clews',
#  u'Physiognomist',
#  u'embellishments',
#  u'how',
#  u'hot',
#  u'hesitatingly',
#  u'hop',
#  u'significance',
#  u'dignified',
#  u'A',
#  u'sighted',
#  u'hoot',
#  u'abstraction',
#  u'MORALS',
#  u'inherent',
#  u'disrated',
#  u'envied',
#  u'shores',
#  u'wrong',
#  u'homewardbound',
#  u'destined',
#  u'L1',
#  u'habitude',
#  u'irradiate',
#  u'HAND',
#  u'domed',
#  u'obscuring',
#  u'Arethusa',
#  u'persuasiveness',
#  u'calves',
#  u'trellised',
#  u'immitigable',
#  u'pyramidical',
#  u'sweatings',
#  u'presiding',
#  u'phrenology',
#  u'baggage',
#  u'Another',
#  u'keeps',
#  u'democratic',
#  u'mightier',
#  u'wing',
#  u'wind',
#  u'wine',
#  u'sprawling',
#  u'snugly',
#  u'betters',
#  u'dreamed',
#  u'Blackstone',
#  u'wiseish',
#  u'profaned',
#  u'narwhales',
#  u'intangible',
#  u'medicament',
#  u'incoherences',
#  u'patrolled',
#  u'fidelity',
#  u'sentry',
#  u'TRUE',
#  u'wrought',
#  u'admirably',
#  u'His',
#  u'Arkite',
#  u'fit',
#  u'Prairies',
#  u'screaming',
#  u'fix',
#  u'mayst',
#  u'HEREABOUTS',
#  u'rescued',
#  u'DANIEL',
#  u'Glimpses',
#  u'bowstring',
#  u'zag',
#  u'nobler',
#  u'wales',
#  u'hidden',
#  u'alpine',
#  u'fin',
#  u'Him',
#  u'feelest',
#  u'grievous',
#  u'copying',
#  u'thrones',
#  u'sneezing',
#  u'slate',
#  u'riggers',
#  u'disturb',
#  u'Commonly',
#  u'LIGHTNING',
#  u'throned',
#  u'effects',
#  u'scarfing',
#  u'elevates',
#  u'interrupt',
#  u'sixteen',
#  u'slats',
#  u'silver',
#  u'vernacular',
#  u'flip',
#  u'represents',
#  u'Start',
#  u'holiness',
#  u'STARBUCK',
#  u'upliftings',
#  u'dumps',
#  u'Shame',
#  u'spotless',
#  u'1750',
#  u'Dutchman',
#  u'Platonists',
#  u'interfering',
#  u'intercepted',
#  u'burial',
#  u'preceded',
#  u'whim',
#  u'Perchance',
#  u'telescope',
#  u'woes',
#  u'warlike',
#  u'series',
#  u'stronger',
#  u'bowls',
#  u'swaths',
#  u'stoneless',
#  u'precedes',
#  u'rind',
#  u'Lionel',
#  u'cathedral',
#  u'allay',
#  u'blinded',
#  u'whip',
#  u'borne',
#  u'preciousness',
#  u'misfortune',
#  u'drove',
#  u'elucidating',
#  u'centaurs',
#  u'ha',
#  u'BENNETT',
#  u'excepting',
#  u'urbane',
#  u're',
#  u'specialties',
#  u'ponderings',
#  u'mend',
#  u'cassock',
#  u'millions',
#  u'outburst',
#  u'Vanity',
#  u'rented',
#  u'stamping',
#  u'assured',
#  u'higgledy',
#  u'foremastmen',
#  u'Work',
#  u'threatened',
#  u'fugitive',
#  u'VISITS',
#  u'assures',
#  u'dragons',
#  u'encountering',
#  u'grapes',
#  u'Trinity',
#  u'crowned',
#  u'estimate',
#  u'solicited',
#  u'knit',
#  u'universally',
#  u'enormous',
#  u'ate',
#  u'Socratic',
#  u'shelves',
#  u'interflow',
#  u'flurry',
#  u'Horn',
#  u'Clinging',
#  u'shipped',
#  u'speedy',
#  u'knobby',
#  u'Human',
#  u'reserving',
#  u'Gall',
#  u'Niger',
#  u'symbolize',
#  u'caught',
#  u'flitting',
#  u'pitchpoling',
#  u'breed',
#  u'Rarmai',
#  u'Peace',
#  u'subtlety',
#  u'playfully',
#  u'Please',
#  u'wast',
#  u'sallies',
#  u'channels',
#  u'wash',
#  u'spinning',
#  u'FIGURED',
#  u'joyousness',
#  u'clamorous',
#  u'wasn',
#  u'sallied',
#  u'attar',
#  u'Dut',
#  u'WHITE',
#  u'specially',
#  u'masted',
#  u'service',
#  u'similarly',
#  u'1775',
#  u'lege',
#  u'needed',
#  u'master',
#  u'blossoms',
#  u'unprofessional',
#  u'legs',
#  u'bitter',
#  u'ranging',
#  u'rummaged',
#  u'Alexander',
#  u'banister',
#  u'Ifs',
#  u'immensities',
#  u'fibrous',
#  u'lunges',
#  u'lumber',
#  u'frowned',
#  u'cisterns',
#  u'wisdom',
#  u'incoherently',
#  u'task',
#  u'mutilated',
#  u'Victory',
#  u'palsy',
#  u'sulphur',
#  u'crawl',
#  u'positively',
#  u').--',
#  u'expanding',
#  u'Icebergs',
#  u'Meshach',
#  u'peril',
#  u'exultation',
#  u'showed',
#  u'icicle',
#  u'coward',
#  u'tree',
#  u'rusty',
#  u'idly',
#  u'nations',
#  u'project',
#  u'predominating',
#  u'exclaimed',
#  u'fragrance',
#  u'Cods',
#  u'spermaceti',
#  u'103',
#  u'feeling',
#  u'besooted',
#  u'Angelo',
#  u'Vice',
#  u'AUGUST',
#  u'willingness',
#  u'broods',
#  u'orbits',
#  u'keeper',
#  u'Keeping',
#  u'craven',
#  u'antagonistic',
#  u'headland',
#  u'Gallipagos',
#  u'Intolerably',
#  u'brawny',
#  u'interblending',
#  u'quay',
#  u'paddled',
#  u'Angels',
#  u'baser',
#  u'dozen',
#  u'Then',
#  u'forgive',
#  u'kidnap',
#  u'wholesome',
#  u'concrete',
#  u'source',
#  u'climate',
#  u'Thee',
#  u'responsible',
#  u'gripe',
#  u'eagerly',
#  u'metallic',
#  u'circumambient',
#  u'NANTUCKET',
#  u'causing',
#  u'absorbed',
#  u'quill',
#  u'They',
#  u'Unicorn',
#  u'warrantry',
#  u'inanimate',
#  u'Jones',
#  u'buck',
#  u'Wise',
#  u'committing',
#  u'transactions',
#  u'thrilled',
#  u'Wish',
#  u'object',
#  u'looming',
#  u'mouts',
#  u'toil',
#  u'mouth',
#  u'inexpressible',
#  u'letter',
#  u'vicinities',
#  u'retaining',
#  u'thicker',
#  u'drought',
#  u'shalt',
#  u'bowings',
#  u'stupid',
#  u'episode',
#  u'bisons',
#  u'grove',
#  u'professor',
#  u'wreck',
#  u'circlings',
#  u'shiftings',
#  u'Magnitude',
#  u'singed',
#  u'Lothario',
#  u'promiscuously',
#  u'nineteenth',
#  u'scream',
#  u'came',
#  u'marvel',
#  u'saying',
#  u'gorings',
#  u'partiality',
#  u'departing',
#  u'Cambyses',
#  u'blazed',
#  u'meetings',
#  u'liest',
#  u'padded',
#  u'Rafters',
#  u'whittling',
#  u'unconditional',
#  u'Paradise',
#  u'pilau',
#  u'tempted',
#  u'cheaply',
#  u'abreast',
#  u'vindictive',
#  u'caper',
#  u'touches',
#  u'copy',
#  u'clicked',
#  u'swamping',
#  u'shuffling',
#  u'quaint',
#  u'bust',
#  u'unmisgiving',
#  u'cougar',
#  u'overwrapped',
#  u'halfspent',
#  u'bliss',
#  u'touched',
#  u'rich',
#  u'upbraiding',
#  u'foolishly',
#  u'codfish',
#  u'Octavo',
#  u'Belated',
#  u'emphatically',
#  u'plate',
#  u'remotest',
#  u'Lima',
#  u'petrified',
#  u'Nevertheless',
#  u'freshening',
#  u'umbilical',
#  u'terrors',
#  u'foremost',
#  u'pocket',
#  u'Petrified',
#  u'altogether',
#  u'X',
#  u'Labor',
#  u'uncleanliness',
#  u'ECUADOR',
#  u'Senators',
#  u'contributes',
#  u'Shipmate',
#  u'spilling',
#  u'nicely',
#  u'blanched',
#  u'accordance',
#  u'dipping',
#  u'patch',
#  u'Rio',
#  u'eyelids',
#  u'fitly',
#  u'flanked',
#  u'Rig',
#  u'boarded',
#  u'wearisome',
#  u'respond',
#  u'distortions',
#  u'blew',
#  u'disaster',
#  u'fair',
#  u'expediency',
#  u'branding',
#  u'conservatories',
#  u'recruit',
#  u'unexpectedly',
#  u'bled',
#  u'flaxen',
#  u'result',
#  u'fail',
#  u'crouch',
#  u'fain',
#  u'resigned',
#  u'hammer',
#  u'best',
#  u'pricking',
#  u'Coleridge',
#  u'lots',
#  u'fanged',
#  u'rings',
#  u'solace',
#  u'droves',
#  u'RESPECTABLE',
#  u'score',
#  u'imposingly',
#  u'scorn',
#  u'pirate',
#  u'preserve',
#  u'discipline',
#  u'queenly',
#  u'never',
#  u'Whalebone',
#  u'parallels',
#  u'extend',
#  u'nature',
#  u'rolled',
#  u'inextricable',
#  u'superficial',
#  u'toilette',
#  u'Flip',
#  u'twinkling',
#  u'extent',
#  u'wheelbarrow',
#  u'tendons',
#  u'dexterously',
#  u'Peterson',
#  u'Arm',
#  u'pity',
#  u'accident',
#  u'hued',
#  u'veer',
#  u'disdain',
#  u'corrupted',
#  u'country',
#  u'damsels',
#  u'cup',
#  u'adventures',
#  u'demanded',
#  u'pestiferously',
#  u'BRACE',
#  u'109',
#  u'wrapping',
#  u'planned',
#  u'dents',
#  u'Gliding',
#  u'argue',
#  u'adapted',
#  u'asked',
#  u'fearlessly',
#  u'lockers',
#  u'brittle',
#  u'pre',
#  u'interregnum',
#  u'topmost',
#  u'honouring',
#  u'vain',
#  u'Christmas',
#  u'caps',
#  u'102',
#  u'charnel',
#  u'clefts',
#  u'gleaming',
#  u'Gently',
#  u'blending',
#  u'humming',
#  u'truthful',
#  u'grazing',
#  u'Instantly',
#  u'signals',
#  u'lighthouse',
#  u'101',
#  u'icebergs',
#  u'hues',
#  u'remained',
#  u'fro',
#  u'Malay',
#  u'.',
#  u'twain',
#  u'much',
#  u'Schmerenburgh',
#  u'interpret',
#  u'privilege',
#  u'fry',
#  u'contraction',
#  u'tallest',
#  u'incompetent',
#  u'cub',
#  u'life',
#  u'fusee',
#  u'spit',
#  u'eastern',
#  u'Poland',
#  u'worker',
#  u'synod',
#  u'befriending',
#  u'lift',
#  u'slap',
#  u'doubts',
#  u'worked',
#  u'haters',
#  u'spin',
#  u'forewarnings',
#  u'skilfully',
#  u'chill',
#  u'commerce',
#  u'charted',
#  u'Annawon',
#  u'sanctorum',
#  u'Beware',
#  u'contingencies',
#  u'stiffest',
#  u'excited',
#  u'employ',
#  u'?--"',
#  u'maned',
#  u'unfulfilments',
#  u"?--'",
#  u'predestinating',
#  u'opulence',
#  u'wonted',
#  u'epicurean',
#  u'BALLENA',
#  u'Crusaders',
#  u'skirts',
#  u'remembering',
#  u'footstep',
#  u'Both',
#  u'equator',
#  u'curvicues',
#  u'actuated',
#  u'locksmith',
#  u'obeying',
#  u'taunts',
#  u'eighteen',
#  u'ghastliness',
#  u'Ginger',
#  u'Sword',
#  u'Gazette',
#  u'LEAP',
#  u'Constantinople',
#  u'hone',
#  u'Denderah',
#  u'damaged',
#  u'Main',
#  u'feebler',
#  u'whimsicalities',
#  u'malefactors',
#  u'credit',
#  u'things',
#  u'Oh',
#  u'shipwrecked',
#  u'rebellion',
#  u'Tahitian',
#  u'Antony',
#  u'swarthy',
#  u'gateways',
#  u'babies',
#  u'visitations',
#  u'provincials',
#  u'toasted',
#  u'voyager',
#  u'fairly',
#  u'spying',
#  u'jerked',
#  u'superstitious',
#  u'marches',
#  u'tuns',
#  u'Maybe',
#  u'surveying',
#  u'tops',
#  u'dexterous',
#  u'seamen',
#  u'boiler',
#  u'voyaged',
#  u'supper',
#  u'Persia',
#  u'blister',
#  u'altar',
#  u'rebut',
#  u'meads',
#  u'peremptory',
#  u'ventricles',
#  u'echoed',
#  u'stillness',
#  u'Table',
#  u'milliner',
#  u'Betty',
#  u'benignity',
#  u'THAR',
#  u'spurred',
#  u'boyhood',
#  u'javelins',
#  u'Sartain',
#  u'sleeps',
#  u'THAT',
#  u'Rabbins',
#  u'sleepy',
#  u'fantastic',
#  u'sleepe',
#  u'disguise',
#  u'maketh',
#  u'patronise',
#  u'shading',
#  u'exclaiming',
#  u'plight',
#  u'rushing',
#  u'succeeding',
#  u'previous',
#  u'Eternity',
#  u'keeled',
#  u'enters',
#  u'ham',
#  u'sciences',
#  u'SPRINGING',
#  u'ease',
#  u'sultanically',
#  u'had',
#  u'ideal',
#  u'hag',
#  u'Figuera',
#  u'hay',
#  u'Connecticut',
#  u'Surely',
#  u'innocent',
#  u'prison',
#  u'hap',
#  u'shoemaker',
#  u'east',
#  u'hat',
#  u'hav',
#  u'unblinkingly',
#  u'explained',
#  u'elevation',
#  u'casually',
#  u'ballasted',
#  u'elders',
#  u'survival',
#  u'thermometer',
#  u'possible',
#  u'lengthen',
#  u'possibly',
#  u'rocket',
#  u'hermaphroditical',
#  u'birth',
#  u'Missouri',
#  u'TAKEN',
#  u'altitude',
#  u'shadow',
#  u'unique',
#  u'tolerable',
#  u'bushy',
#  u'desire',
#  u'county',
#  u'articulated',
#  u'scan',
#  u'phrensied',
#  u'tapering',
#  u'triumphal',
#  u'Harvard',
#  u'marquee',
#  u'repassing',
#  u'Ezekiel',
#  u'remind',
#  u'pavement',
#  u'steps',
#  u'Aristotle',
#  u'scuppers',
#  u'Further',
#  u'continuation',
#  u'vats',
#  u'warping',
#  u'right',
#  u'old',
#  u'jackets',
#  u'crowd',
#  u'people',
#  u'Literally',
#  u'creed',
#  u'crown',
#  u'System',
#  u'captive',
#  u'sterns',
#  u'fagot',
#  u'Between',
#  u'Rachel',
#  u'prick',
#  u'animate',
#  u'Canaller',
#  u'enemies',
#  u'gasps',
#  u'perchance',
#  u'ruffled',
#  u'for',
#  u'bottom',
#  u'goggling',
#  u'inhuman',
#  u'plucked',
#  u'witty',
#  u'foe',
#  u'ruffles',
#  u'fog',
#  u'summoned',
#  u'pondered',
#  u'serpents',
#  u'indication',
#  u'Epitome',
#  u'dined',
#  u'pinched',
#  u'Watts',
#  u'shakes',
#  u'sisterly',
#  u'mildewed',
#  u'trencher',
#  u'post',
#  u'terraces',
#  u'clearer',
#  u'binder',
#  u'Thine',
#  u'yoke',
#  ...}

# %%
#lexical  richness the % of unique words used

lx_rich(text1)
# Out:
# 0.07406285585022564

# %%
lx_rich(text3)
# Out:
# 0.06230453042623537

# %%
lx_rich(sent1)
# Out:
# 1.0

# %%
#Most frequent words

fdist1=FreqDist(text1)
fdist1.most_common(50)
# Out:
# [(u',', 18713),
#  (u'the', 13721),
#  (u'.', 6862),
#  (u'of', 6536),
#  (u'and', 6024),
#  (u'a', 4569),
#  (u'to', 4542),
#  (u';', 4072),
#  (u'in', 3916),
#  (u'that', 2982),
#  (u"'", 2684),
#  (u'-', 2552),
#  (u'his', 2459),
#  (u'it', 2209),
#  (u'I', 2124),
#  (u's', 1739),
#  (u'is', 1695),
#  (u'he', 1661),
#  (u'with', 1659),
#  (u'was', 1632),
#  (u'as', 1620),
#  (u'"', 1478),
#  (u'all', 1462),
#  (u'for', 1414),
#  (u'this', 1280),
#  (u'!', 1269),
#  (u'at', 1231),
#  (u'by', 1137),
#  (u'but', 1113),
#  (u'not', 1103),
#  (u'--', 1070),
#  (u'him', 1058),
#  (u'from', 1052),
#  (u'be', 1030),
#  (u'on', 1005),
#  (u'so', 918),
#  (u'whale', 906),
#  (u'one', 889),
#  (u'you', 841),
#  (u'had', 767),
#  (u'have', 760),
#  (u'there', 715),
#  (u'But', 705),
#  (u'or', 697),
#  (u'were', 680),
#  (u'now', 646),
#  (u'which', 640),
#  (u'?', 637),
#  (u'me', 627),
#  (u'like', 624)]

# %%
#plotting the word counts
fdist1.plot(50,cumulative=True)

# %%
#Fine grained selection of words

V=set(text1)
lv=[i for i in V if len(i)>15]

sorted(lv)
# Out:
# [u'CIRCUMNAVIGATION',
#  u'Physiognomically',
#  u'apprehensiveness',
#  u'cannibalistically',
#  u'characteristically',
#  u'circumnavigating',
#  u'circumnavigation',
#  u'circumnavigations',
#  u'comprehensiveness',
#  u'hermaphroditical',
#  u'indiscriminately',
#  u'indispensableness',
#  u'irresistibleness',
#  u'physiognomically',
#  u'preternaturalness',
#  u'responsibilities',
#  u'simultaneousness',
#  u'subterraneousness',
#  u'supernaturalness',
#  u'superstitiousness',
#  u'uncomfortableness',
#  u'uncompromisedness',
#  u'undiscriminating',
#  u'uninterpenetratingly']

# %%
# Collocations - Words that make sense when the occur together like red wine
# Bigrams - A pair of words

print(text3.collocations())
# Out:
# said unto; pray thee; thou shalt; thou hast; thy seed; years old;
# spake unto; thou art; LORD God; every living; God hath; begat sons;
# seven years; shalt thou; little ones; living creature; creeping thing;
# savoury meat; thirty years; every beast
# None

# %%
# Counting other things
fdist2=FreqDist(len(w) for w in text1)
fdist2
# Out:
# FreqDist({1: 47933,
#           2: 38513,
#           3: 50223,
#           4: 42345,
#           5: 26597,
#           6: 17111,
#           7: 14399,
#           8: 9966,
#           9: 6428,
#           10: 3528,
#           11: 1873,
#           12: 1053,
#           13: 567,
#           14: 177,
#           15: 70,
#           16: 22,
#           17: 12,
#           18: 1,
#           20: 1})

# %%
# fdist = FreqDist(samples)	create a frequency distribution containing the given samples
# fdist[sample] += 1	increment the count for this sample
# fdist['monstrous']	count of the number of times a given sample occurred
# fdist.freq('monstrous')	frequency of a given sample
# fdist.N()	total number of samples
# fdist.most_common(n)	the n most common samples and their frequencies
# for sample in fdist:	iterate over the samples
# fdist.max()	sample with the greatest count
# fdist.tabulate()	tabulate the frequency distribution
# fdist.plot()	graphical plot of the frequency distribution
# fdist.plot(cumulative=True)	cumulative plot of the frequency distribution
# fdist1 |= fdist2	update fdist1 with counts from fdist2
# fdist1 < fdist2	test if samples in fdist1 occur less frequently than in fdist2

#Some other functions- isdigit, istitle, endswith
sorted(wd for wd in set(text3) if wd.istitle() and len(wd) > 12)
# Out:
# [u'Jegarsahadutha', u'Zaphnathpaaneah']

# %% [markdown]
# # Nested Code blocks & looping with conditions

# %%
list_w=[]
for w in text4:
    if w not in list_w:
        if w.endswith('nity'):
            list_w.append(w)
print(list_w)
# Out:
# [u'humanity', u'Christianity', u'solemnity', u'opportunity', u'community', u'dignity', u'fraternity', u'immunity', u'impunity', u'importunity', u'unity', u'Humanity', u'Immunity', u'Opportunity', u'indignity', u'eternity']

# %% [markdown]
# # Automatic NL Understanding

# %% [markdown]
# ### Some issues with NL understanding are
#
# * Word Sense disambiguation
# * Pronoun resolution
# * General language output
# * Machine translation
# * Spoken Dialog Systems
# * Textual Entailment
# * Cannot perform real world applications

# %% [markdown]
# * Texts are represented in Python using lists: ['Monty', 'Python']. We can use indexing, slicing, and the len() function on lists.
#
# * A word "token" is a particular appearance of a given word in a text; a word "type" is the unique form of the word as a particular sequence of letters. We count word tokens using len(text) and word types using len(set(text)).
#
# * We obtain the vocabulary of a text t using sorted(set(t)).
#
# * We operate on each item of a text using [f(x) for x in text].
#
# * To derive the vocabulary, collapsing case distinctions and ignoring punctuation, we can write set(w.lower() for w in text if w.isalpha()).
#
# * We process each word in a text using a for statement, such as for w in t: or for word in text:. This must be followed by the colon character and an indented block of code, to be executed each time through the loop.
#
# * We test a condition using an if statement: if len(word) < 5:. This must be followed by the colon character and an indented block of code, to be executed only if the condition is true.
#
# * A frequency distribution is a collection of items along with their frequency counts (e.g., the words of a text and their frequency of appearance).
#
# * A function is a block of code that has been assigned a name and can be reused. Functions are defined using the def keyword, as in def mult(x, y); x and y are parameters of the function, and act as placeholders for actual data values.
#
# * A function is called by specifying its name followed by zero or more arguments inside parentheses, like this: texts(), mult(3, 4), len(text1)
